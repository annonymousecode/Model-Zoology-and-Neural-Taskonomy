# %%
import pandas as pd
import pickle

# %%
task_dictlist = [
    
    {'taskname': 'Autoencoder', 'model': 'autoencoding', 'category': '2D',
        'description': 'Image compression and decompression'},
    
    {'taskname': 'Object Classification', 'model': 'class_object', 'category': 'Semantic',
        'description': '1000-way object classification (via knowledge distillation from ImageNet).'},
    
    {'taskname': 'Scene Classification', 'model': 'class_scene', 'category': 'Semantic',
        'description': 'Scene Classification (via knowledge distillation from MIT Places).'},
    
    {'taskname': 'Curvatures', 'model': 'curvature', 'category': '3D',
        'description': 'Magnitude of 3D principal curvatures'},
    
    {'taskname': 'Colorization', 'model': 'colorization', 'category': None,
        'description': 'Colorizing input grayscale images.'},
    
    {'taskname': 'Denoising', 'model': 'denoising', 'category': 'Other',
        'description': 'Uncorrupted version of corrupted image.'},
    
    {'taskname': 'Euclidean Depth', 'model': 'depth_euclidean', 'category': '3D',
        'description': 'Depth estimation'},
    
    {'taskname': 'Z-Buffer Depth', 'model': 'depth_zbuffer', 'category': '3D',
        'description': 'Depth estimation.'},
    
    {'taskname': 'Occlusion Edges', 'model': 'edge_occlusion', 'category': '3D',
        'description': 'Edges which include parts of the scene.'},
    
    {'taskname': 'Texture Edges', 'model': 'edge_texture', 'category': '2D',
        'description': 'Edges computed from RGB only (texture edges).'},
    
    {'taskname': 'Egomotion', 'model': 'egomotion', 'category': 'Geometric',
        'description': 'Odometry (camera poses) given three input images.'},
    
    {'taskname': 'Camera Pose (Fixated)', 'model': 'fixated_pose', 'category': 'Geometric',
        'description': 'Relative camera pose with matching optical centers.'},
    
    {'taskname': 'Inpainting', 'model': 'inpainting', 'category': '2D',
        'description': 'Filling in masked center of image.'},
    
    {'taskname': 'Jigsaw', 'model': 'jigsaw', 'category': 'Geometric',
        'description': 'Putting scrambled image pieces back together.'},
    
    {'taskname': '2D Keypoints', 'model': 'keypoints2d', 'category': '2D',
        'description': 'Keypoint estimation from RGB-only (texture features).'},
    
    {'taskname': '3D Keypoints', 'model': 'keypoints3d', 'category': '3D',
        'description': '3D Keypoint estimation from underlying scene 3D.'},
    
    {'taskname': 'Camera Pose (Nonfixated)', 'model': 'nonfixated_pose', 'category': 'Geometric',
        'description': 'Relative camera pose with distinct optical centers.'},
    
    {'taskname': 'Surface Normals', 'model': 'normal', 'category': 'Other',
        'description': 'Pixel-wise surface normals.'},
    
    {'taskname': 'Point Matching', 'model': 'point_matching', 'category': 'Geometric',
        'description': 'Classifying if centers of two images match or not.'},
    
    {'taskname': 'Reshading', 'model': 'reshading', 'category': '3D',
        'description': 'Reshading with new lighting placed at camera location.'},
    
    {'taskname': 'Room Layout', 'model': 'room_layout', 'category': 'Geometric',
        'description': 'Orientation and aspect ratio of cubic room layout.'},
    
    {'taskname': 'Semantic Segmentation', 'model': 'segment_semantic', 'category': 'Semantic',
        'description': 'Pixel-wise semantic labeling (via knowledge distillation from MS COCO).'},
    
    {'taskname': 'Unsupervised 2.5D Segmentation', 'model': 'segment_unsup25d', 'category': '3D',
        'description': 'Segmentation (graph cut approximation) on RGB-D-Normals-Curvature image.'},
    
    {'taskname': 'Unsupervised 2D Segmentation', 'model': 'segment_unsup2d', 'category': '2D',
        'description': 'Segmentation (graph cut approximation) on RGB.'},
    
    {'taskname': 'Vanishing Point', 'model': 'vanishing_point', 'category': 'Geometric',
        'description': 'Three Manhattan-world vanishing points.'}
]

task_df = pd.DataFrame(task_dictlist)

# %%
task_df
# Out:
#                           taskname             model   category  \
# 0                      Autoencoder      autoencoding         2D
# 1            Object Classification      class_object   Semantic
# 2             Scene Classification       class_scene   Semantic
# 3                       Curvatures         curvature         3D
# 4                     Colorization      colorization       None
# 5                        Denoising         denoising      Other
# 6                  Euclidean Depth   depth_euclidean         3D
# 7                   Z-Buffer Depth     depth_zbuffer         3D
# 8                  Occlusion Edges    edge_occlusion         3D
# 9                    Texture Edges      edge_texture         2D
# 10                       Egomotion         egomotion  Geometric
# 11           Camera Pose (Fixated)      fixated_pose  Geometric
# 12                      Inpainting        inpainting         2D
# 13                          Jigsaw            jigsaw  Geometric
# ...

# %%
task_df.to_csv('task_definitions.csv', index = None)
